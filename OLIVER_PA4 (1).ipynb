# %% [markdown]
# # EXPERIMENT 4: DATA WRANGLING AND DATA VISUALIZATION

# %% [markdown]
# Name: Justin Ylerlee D. Oliver

# %% [markdown]
# Section 2ECE-B

# %% [markdown]
# ## A. VISAYAS COMMUNICATION DATAFRAME

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
board = pd.read_excel('board2.xlsx')
board
# Out:
#    Name  Gender             Track  Hometown  Math  Electronics  GEAS  \
# 0    S1    Male   Instrumentation     Luzon    58           89    75
# 1    S2  Female     Communication  Mindanao    52           75    90
# 2    S3  Female   Instrumentation  Mindanao    83           74    77
# 3    S4    Male   Instrumentation   Visayas    65           58    91
# 4    S5    Male     Communication     Luzon    59           86    43
# 5    S6  Female  Microelectronics   Visayas    88           45    86
# 6    S7  Female   Instrumentation     Luzon    66           60    60
# 7    S8    Male   Instrumentation     Luzon    49           81    64
# 8    S9    Male   Instrumentation     Luzon    50           36    63
# 9   S10    Male  Microelectronics  Mindanao    80           84    61
# 10  S11  Female     Communication   Visayas    48           56    48
# 11  S12    Male     Communication   Visayas    89           67    84
# 12  S13  Female  Microelectronics     Luzon    88           35    83
# ...

# %%
board["Average"] = board [["Math", "Electronics", "GEAS", "Communication"]] .mean(axis=1)
board
# Out:
#    Name  Gender             Track  Hometown  Math  Electronics  GEAS  \
# 0    S1    Male   Instrumentation     Luzon    58           89    75
# 1    S2  Female     Communication  Mindanao    52           75    90
# 2    S3  Female   Instrumentation  Mindanao    83           74    77
# 3    S4    Male   Instrumentation   Visayas    65           58    91
# 4    S5    Male     Communication     Luzon    59           86    43
# 5    S6  Female  Microelectronics   Visayas    88           45    86
# 6    S7  Female   Instrumentation     Luzon    66           60    60
# 7    S8    Male   Instrumentation     Luzon    49           81    64
# 8    S9    Male   Instrumentation     Luzon    50           36    63
# 9   S10    Male  Microelectronics  Mindanao    80           84    61
# 10  S11  Female     Communication   Visayas    48           56    48
# 11  S12    Male     Communication   Visayas    89           67    84
# 12  S13  Female  Microelectronics     Luzon    88           35    83
# ...

# %%
VisComm = board.loc[(board["Hometown"] == "Visayas") & (board["Track"] == "Communication"), ["Name", "Gender","Math","Electronics","Average"]]
VisComm
# Out:
#    Name  Gender  Math  Electronics  Average
# 10  S11  Female    48           56    54.75
# 11  S12    Male    89           67    76.00
# 17  S18    Male    81           40    63.50
# 21  S22  Female    64           39    62.50
# 27  S28    Male    85           53    67.75

# %%
VisComm = board.loc[(board["Hometown"] == "Visayas") & (board["Track"] == "Communication"), ["Name", "Gender","Math","Electronics","Average"]]
VisComm
# Out:
#    Name  Gender  Math  Electronics  Average
# 10  S11  Female    48           56    54.75
# 11  S12    Male    89           67    76.00
# 17  S18    Male    81           40    63.50
# 21  S22  Female    64           39    62.50
# 27  S28    Male    85           53    67.75

# %%
VisComm.shape[0]
# Out:
# 5

# %% [markdown]
# ## B. VISAYAS FEMALE DATAFRAME

# %%
VisFemale = board.loc[(board['Hometown'] == 'Visayas') & (board['Gender'] == 'Female'),['Name','Track','GEAS','Electronics','Average']]
VisFemale
# Out:
#    Name             Track  GEAS  Electronics  Average
# 5    S6  Microelectronics    86           45    75.50
# 10  S11     Communication    48           56    54.75
# 20  S21  Microelectronics    68           51    68.50
# 21  S22     Communication    89           39    62.50
# 23  S24  Microelectronics    60           45    57.75
# 25  S26   Instrumentation    83           47    65.75

# %%
VF = VisFemale[VisFemale['Average'] >= 60]
VF
# Out:
#    Name             Track  GEAS  Electronics  Average
# 5    S6  Microelectronics    86           45    75.50
# 20  S21  Microelectronics    68           51    68.50
# 21  S22     Communication    89           39    62.50
# 25  S26   Instrumentation    83           47    65.75

# %% [markdown]
# ## C. CATEGORY-AVERAGE VISUALIZATION

# %% [markdown]
# ## A.

# %%
trackmean = board.groupby('Track')['Average'].mean().round(2)
gendermean = board.groupby('Gender')['Average'].mean().round(2)
hometownmean = board.groupby('Hometown')['Average'].mean().round(2)

# %% [markdown]
# ## B.

# %%
trackmean
# Out:
# Track
# Communication       67.97
# Instrumentation     65.22
# Microelectronics    67.50
# Name: Average, dtype: float64

# %%
gendermean
# Out:
# Gender
# Female    66.62
# Male      67.18
# Name: Average, dtype: float64

# %%
hometownmean
# Out:
# Hometown
# Luzon       68.08
# Mindanao    66.68
# Visayas     65.75
# Name: Average, dtype: float64

# %% [markdown]
# ## C.

# %%
plt.subplots(1,3, figsize=(16, 5))

plt.subplot(1,3,1)
plt.bar(trackmean.index, trackmean.values)
plt.ylim(0,100)
plt.title('Mean Average by Track')
plt.subplot(1,3,2)
plt.bar(gendermean.index, gendermean.values)
plt.ylim(0,100)
plt.title('Mean Average by Gender')
plt.subplot(1,3,3)
plt.bar(hometownmean.index, hometownmean.values)
plt.ylim(0,100)
plt.title('Mean Average by Hometown')
# Out:
# Text(0.5, 1.0, 'Mean Average by Hometown')

# %% [markdown]
# ## D.

# %% [markdown]
# Track: Of the three tracks, Communication has the highest mean average (67.97), followed by Microelectronics (67.50) and Instrumentation (65.22).
# Gender: The mean average for males is higher (67.18) than that of females (66.62).
# Hometown: At 68.08, Luzon has the highest mean average, followed by Mindanao at 66.68 and Visayas at 65.75.
